# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import matplotlib.dates as mdates
from datetime import datetime
sns.set()

import sqlite3

import sys
sys.path.append(r'C:\Users\azuka\Documents\Python Scripts\common_functions')
from common_functions import check_values

# %% [markdown]
# # connection

# %%
cnxn = sqlite3.connect(r'C:\Users\azuka\Documents\Materials\Non Degree\04 SQL\Dataset\Final Project\olist.db')

# %% [markdown]
# # explore tables

# %%
pd.read_sql('''
                 SELECT 
    name
FROM 
    sqlite_schema
WHERE 
    type ='table' AND name NOT LIKE 'sqlite_%';
                 ''',cnxn)
# Out:
#                                 name
# 0       olist_order_customer_dataset
# 1                olist_order_dataset
# 2        olist_order_reviews_dataset
# 3       olist_order_payments_dataset
# 4          olist_order_items_dataset
# 5             olist_products_dataset
# 6              olist_sellers_dataset
# 7          olist_geolocation_dataset
# 8  product_category_name_translation

# %%
check_values(pd.read_sql('''
            select * from product_category_name_translation
            --limit 1000
            ''',cnxn))
# Out:
#                         features data_type  nan_total  nan_pct  unique  \
# 0                          index     int64          0      0.0      71
# 1          product_category_name    object          0      0.0      71
# 2  product_category_name_english    object          0      0.0      71
#
#                                   values_ex
# 0                                  [63, 48]
# 1                 [consoles_games, bebidas]
# 2  [sports_leisure, books_general_interest]

# %%
pd.read_sql('''
            select product_category_name, count(*) from product_category_name_translation
            group by 1 order by 2 desc
            ''',cnxn)
# Out:
#         product_category_name  count(*)
# 0       utilidades_domesticas         1
# 1              telefonia_fixa         1
# 2                   telefonia         1
# 3    tablets_impressao_imagem         1
# 4     sinalizacao_e_seguranca         1
# ..                        ...       ...
# 66         artes_e_artesanato         1
# 67                      artes         1
# 68          alimentos_bebidas         1
# 69                  alimentos         1
# 70  agro_industria_e_comercio         1
#
# [71 rows x 2 columns]

# %%
check_values(pd.read_sql('''
            select * from olist_products_dataset
            --limit 1000
            ''',cnxn))
# Out:
#                      features data_type  nan_total  nan_pct  unique  \
# 0                       index     int64          0     0.00   32951
# 1                  product_id    object          0     0.00   32951
# 2       product_category_name    object        610     1.85      73
# 3         product_name_lenght   float64        610     1.85      66
# 4  product_description_lenght   float64        610     1.85    2960
# 5          product_photos_qty   float64        610     1.85      19
# 6            product_weight_g   float64          2     0.01    2204
# 7           product_length_cm   float64          2     0.01      99
# 8           product_height_cm   float64          2     0.01     102
# 9            product_width_cm   float64          2     0.01      95
#
#                                            values_ex
# 0                                      [16211, 2476]
# 1  [36a3aa7d9d4e2bfcd7edb9c2abf061a6, 32b9c3230a5...
# 2                    [artes, fashion_roupa_feminina]
# ...

# %%
pd.read_sql('''
            select * from olist_order_items_dataset
            -- limit 10
            ''',cnxn)
# Out:
#          index                          order_id  order_item_id  \
# 0            0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1            1  00018f77f2f0320c557190d7a144bdd3              1
# 2            2  000229ec398224ef6ca0657da4fc703e              1
# 3            3  00024acbcdf0a6daa1e931b038114c75              1
# 4            4  00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...        ...                               ...            ...
# 112645  112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# ...

# %% [markdown]
# berapa persen product yg dipesan yg kategorinya null

# %%
pd.read_sql('''
            select count(dist) from olist_order_items_dataset oi
            left join olist_products_dataset p 
                on oi.product_id = p.product_id
            left join product_category_name_translation c
                on p.product_category_name = c.product_category_name
            -- where c.product_category_name is null
            -- limit 10
            ''',cnxn)
# Out:
#        index                          order_id  order_item_id  \
# 0        123  0046e1d57f4c07c8c92ab26be8c3dfc0              1
# 1        125  00482f2670787292280e0a8153d82467              1
# 2        132  004f5d8f238e8908e6864b874eda3391              1
# 3        142  0057199db02d1a5ef41bacbf41f8f63b              1
# 4        171  006cb7cafc99b29548d4f412c7f9f493              1
# ...      ...                               ...            ...
# 1622  112306  ff24fec69b7f3d30f9dc1ab3aee7c179              1
# 1623  112333  ff3024474be86400847879103757d1fd              1
# 1624  112350  ff3a45ee744a7c1f8096d2e72c1a23e4              1
# 1625  112438  ff7b636282b98e0aa524264b295ed928              1
# 1626  112501  ffa5e4c604dea4f0a59d19cc2322ac19              2
#
#                             product_id                         seller_id  \
# 0     ff6caf9340512b8bf6d2a2a6df032cfa  38e6dada03429a47197d5d584d793b41
# ...

# %% [markdown]
# # Laporan

# %% [markdown]
# ## Objektif
# - Jenis produk yang paling banyak dibeli
# - Jenis produk yang memiliki repeat buyer paling banyak
#   - kriteria repeat buyer:
#     - 1 order every month
